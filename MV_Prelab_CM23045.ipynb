# %% [markdown]
# <a href="https://colab.research.google.com/github/TejasKayarkar03/Machine-Vision-CM45/blob/main/MV_Prelab_CM23045.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd9ec1e7-b49b-41cd-8ab6-5764f7254d5c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd9ec1e7-b49b-41cd-8ab6-5764f7254d5c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image_path = list(uploaded.keys())[0]

img = cv2.imread(image_path)

# Convert BGR to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(6,6))
plt.imshow(img_rgb)
plt.title("Loaded Image")
plt.axis("off")
plt.show()

# %%
print("Shape:", img.shape)
print("Height:", img.shape[0], "pixels")
print("Width:", img.shape[1], "pixels")
print("Channels:", img.shape[2])
print("Data Type:", img.dtype)
print("Total Pixels:", img.shape[0]*img.shape[1])
# Out:
# Shape: (609, 1000, 3)
# Height: 609 pixels
# Width: 1000 pixels
# Channels: 3
# Data Type: uint8
# Total Pixels: 609000

# %%
b, g, r = cv2.split(img)

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(b, cmap='gray')
plt.title("Blue Channel")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(g, cmap='gray')
plt.title("Green Channel")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(r, cmap='gray')
plt.title("Red Channel")
plt.axis("off")

plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(6,6))
plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %%
cv2.imwrite("output_image.jpg", img)

print("Image saved successfully.")
# Out:
# Image saved successfully.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8879cb67-cd47-4424-b1d3-ea27690294da" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8879cb67-cd47-4424-b1d3-ea27690294da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
video_path = list(uploaded.keys())[0]

cap = cv2.VideoCapture(video_path)

print("Video Opened:", cap.isOpened())

fps = cap.get(cv2.CAP_PROP_FPS)

frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))

height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

print("FPS:", fps)
print("Frames:", frames)
print("Resolution:", width, "x", height)

cap.release()
# Out:
# Video Opened: True
# FPS: 30.0
# Frames: 180
# Resolution: 854 x 480

# %%
cap = cv2.VideoCapture(video_path)

ret, frame = cap.read()

if ret:
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(6,6))
    plt.imshow(frame)
    plt.title("First Video Frame")
    plt.axis("off")

cap.release()
